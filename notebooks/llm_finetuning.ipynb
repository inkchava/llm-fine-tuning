# %% [markdown]
# # LLM Fine-Tuning & Evaluation
#
# Author: Isaree Chavanapanit
#
# Objective:
# Fine-tune Qwen2.5-0.5B-Instruct on multiple-choice machine learning questions using supervised instruction tuning.
#
# Technologies:
#
# • PyTorch
# • Hugging Face
# • Transformers
# • TRL

# %% [markdown]
# ---
# ## Part 0: Environment Setup
#
# This cell installs and imports the required libraries.

# %%
import sys
IS_COLAB = 'google.colab' in sys.modules
if IS_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    # %cd /content/drive/MyDrive/cs189/hw/hw5
    ! pip install -q transformers==4.57.2 accelerate datasets trl bitsandbytes
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/cs189/hw/hw5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 117.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.4/517.4 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 45.5 MB/s eta 0:00:00

# %%
import os
import re
import math
import pandas as pd
import torch
from datasets import Dataset, concatenate_datasets, load_dataset, load_from_disk
from trl import SFTTrainer, SFTConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#MAKE SURE YOU ARE USING GPU
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ---
# ## Part 1: Configuration & Model Loading
#
# Here we define all our settings and load the base model.
#
# **Model Design (L):** We select `Qwen/Qwen2.5-0.5B-Instruct`.

# %%
# ============================================================================
# === CONFIGURATION - ALL SETTINGS IN ONE PLACE ===
# ============================================================================

# --- Model Configuration ---
MODEL_NAME = "Qwen/Qwen2.5-0.5B-Instruct" # YOU CANNOT CHANGE THIS

# --- Dataset Configuration ---
#TODO: REPLACE WITH YOUR OWN PATH
MCQ_CSV_PATH = "hw5_sample_eval.csv"  # Path to CS189 MCQ sample eval dataset

# --- Training Configuration (feel free to adjust!) ---
TRAIN_BATCH_SIZE = 4
GRADIENT_ACCUMULATION_STEPS = 20
WARMUP_STEPS = 10
MAX_STEPS = 150  # or set num_train_epochs instead
LEARNING_RATE = 2e-5
WEIGHT_DECAY = 0.01
LR_SCHEDULER_TYPE = "linear"
OPTIM = "adamw_8bit"  # requires bitsandbytes
SEED = 189

# --- Evaluation Configuration ---
EVAL_MAX_NEW_TOKENS = 64  # How many tokens to generate for inference
OUTPUT_DIR = "./mcq_finetuned_model"

# %%
# === Load base model & tokenizer ===
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# Ensure we have a pad token for training
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device_map="auto" if torch.cuda.is_available() else None,
)
model.resize_token_embeddings(len(tokenizer))
model.to(device)
model.eval()
print('Model loaded.')
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Model loaded.

# %% [markdown]
# ---
# ## Part 2: Data Preparation
#
# **Learning Problem (P):** We need to format our raw CSV data into training examples.
#
# We define helper functions to:
# 1.  Load the CSV.
# 2.  Build a "prompt" (Question + Options).
# 3.  Build the full "SFT text" (Prompt + Answer) using the model's chat template.

# %%
# === MCQ helpers ===
LETTER_SET = set(list("ABCDE"))

def load_mcq_dataset(csv_path: str = MCQ_CSV_PATH):
    """Load the CS189 MCQ dataset.

    Expected columns:
        - question
        - A, B, C, D, E
        - answer (single letter A-E)
    """
    df = pd.read_csv(csv_path)
    required = ["question", "A", "B", "C", "D", "E", "answer"]
    missing = [c for c in required if c not in df.columns]
    if missing:
        raise ValueError(f"Missing required columns in MCQ CSV: {missing}")

    df = df.copy()
    df["answer"] = (
        df["answer"]
        .astype(str)
        .str.strip()
        .str.upper()
    )
    df = df[df["answer"].isin(LETTER_SET)].reset_index(drop=True)
    return df

def build_mcq_prompt(row):
    """Prompt for inference: instruction + question + options.

    The model is expected to answer with the correct letter in \\boxed{} format.
    """
    q = str(row["question"]).strip()
    options = "\n".join([
        f"A. {row['A']}",
        f"B. {row['B']}",
        f"C. {row['C']}",
        f"D. {row['D']}",
        f"E. {row['E']}",
    ])
    prompt = (
        "Choose exactly one correct option from A, B, C, D, and E.\n"
        "Return your answer inside a LaTeX box.\n\n"
        f"{q}\n\n{options}\n\nAnswer:"
    )
    return prompt

# %% [markdown]
# ### Understanding the Chat Format (OpenAI Style)
#
# To fine-tune a chat model, we need to structure our data as a conversation. This is often called the **OpenAI Chat Format** or **Messages Format**.
#
# Instead of a single string of text, each example is a list of dictionaries, where each dictionary represents a message in the conversation:
# -   `{"role": "user", "content": "..."}`: The input prompt or question.
# -   `{"role": "assistant", "content": "..."}`: The model's desired response.
#
# For our MCQ task, we structure it as:
# 1.  **User**: "Choose exactly one correct option... [Question] ... [Options]"
# 2.  **Assistant**: "\\boxed{A}"
#
# We then use `tokenizer.apply_chat_template()` to convert this structured list into the specific string format that the model expects (e.g., adding special tokens like `<|im_start|>user...<|im_end|>`).

# %%
def parse_choice_from_boxed(text: str):
    """Parse an MCQ choice A–E from the model output.

    We first look for a literal '\\boxed{X}' pattern. If not found, we
    fallback to the last standalone A-E in the decoded text.
    """
    if text is None:
        return None
    # Direct \\boxed{A} ... \\boxed{E}
    m = re.search(r"\\boxed\{\s*([A-E])\s*\}", text)
    if m:
        return m.group(1)
    # Fallback: last standalone A–E
    letters = re.findall(r"\b([A-E])\b", text.upper())
    if letters:
        return letters[-1]
    return None

# %% [markdown]
# ### **Load and Format the (Eval) Dataset**
#
# We load the MCQ dataset and apply the formatting function.
# These are sample eval sets we provided. The actual test set you would be making predictions will be a mix of different questions (Full details are provided in the accompanying PDF)

# %%
# === Load MCQ CSV (Evaluation Data) ===
try:
    mcq_df = load_mcq_dataset(MCQ_CSV_PATH)
    print(f"Loaded MCQ dataset with {len(mcq_df)} rows from {MCQ_CSV_PATH}.")
except Exception as e:
    mcq_df = None
    print("Error loading MCQ CSV — check MCQ_CSV_PATH.")
    raise e
mcq_df
# Out:
# Loaded MCQ dataset with 25 rows from hw5_sample_eval.csv.
#             id                                           question  \
# 0        mcq_1  Peanut wants to train a model to accurately cl...
# 1        mcq_2  Consider a binary classification data set with...
# 2        mcq_3  Again, consider a binary classification data s...
# 3        mcq_4  Assume we are given X ∈ Rn×d and y ∈ Rn for n ...
# 4        mcq_5  Which of the following statements are TRUE reg...
# 5        mcq_6  Which of the following statements are TRUE reg...
# 6        mcq_7  If the model resulting from Ridge regression i...
# 7        mcq_8  Which of the following statements are TRUE abo...
# 8        mcq_9  Which of the following statements are TRUE abo...
# 9       mcq_10  Which of the following statements are TRUE abo...
# 10      mcq_11  Which of the following statements are TRUE abo...
# 11      mcq_12  Which of the following statements are TRUE abo...
# 12      mcq_13  Assume a linear model Y = Xw∗ + z, where z ∼ N...
# 13      mcq_14  How will increasing λ in Equation 1 affect the...
# 14      mcq_15  For this question, X ∈ R^{n×d} denotes an inpu...
# 15      mcq_16  Suppose you have a dataset where the label is ...
# 16      mcq_17  You are walking down Shattuck Ave. when you fi...
# 17      mcq_18  Consider the setup of the previous problem (Pr...
# 18      mcq_19  Consider a binary classification problem with ...
# 19      mcq_20  Julia is using SNE to visualize her high-dimen...
# 20      mcq_21  Which of the following is a problem with the s...
# 21  fa2025_Q3A  In the bias–variance decomposition, what does ...
# 22  fa2025_Q3B  In the bias–variance decomposition, the expres...
# 23  fa2025_Q3C  If we reduce the L1 regularization parameter λ...
# 24  fa2025_Q3D  Suppose we change the feature basis to a const...
#
#                                                     A  \
# 0                                          High bias.
# 1                                      Close to zero.
# 2        The precision is 0.1, and the recall is 0.9.
# 3                   y′ = [ y; 0d ], X′ = [ X; √λ Id ]
# 4   “Every entry of a matrix is non-negative” is a...
# 5   In the Bayesian MAP interpretation, Lasso regr...
# 6   Collect new data to increase the training data...
# 7   After a gradient descent update step, the obje...
# 8   The value of cross-entropy loss is always non-...
# 9   During the k-fold cross validation process, pr...
# 10  Multiplying all columns in X by a factor of tw...
# 11  Typically, the weights in all hidden layers ar...
# 12                                Bias will increase.
# 13                            Variance will increase.
# 14  For all X and true linear predictors w∗ ∈ R^d,...
# 15                 As n → ∞, Acctrain approaches 50%.
# 16                                               5/10
# 17                                               5/10
# 18                  Low bias implies a high F1 score.
# 19  This is expected due to the nonconvexity of th...
# 20  Sigmoid is prone to vanishing gradients at ext...
# 21                                               Bias
# 22                                               Bias
# 23                                          Increases
# 24                                   Remains the same
#
#                                                     B  \
# 0                                           Low bias.
# 1                                       Close to 0.1.
# 2        The precision is 0.9, and the recall is 0.1.
# 3                   y′ = [ y; 1d ], X′ = [ X; √λ Id ]
# 4   The singular values of a positive semi-definit...
# 5   In Lasso regression, as the regularization coe...
# 6   Repeat the current data twice to increase the ...
# 7   There is always a unique steepest descent dire...
# 8   Cross-entropy loss is only suitable for binary...
# 9   During the k-fold cross validation process, pr...
# 10  Multiplying the first column in X by a factor ...
# 11  If using the mean squared error loss, the weig...
# 12                                Bias will decrease.
# 13                            Variance will decrease.
# 14            For all X and y, ∥wridge∥_2 ≤ ∥wOLS∥_2.
# 15                   As n → ∞, Accval approaches 50%.
# 16                              between 5/10 and 9/10
# 17                              between 5/10 and 9/10
# 18              Low variance implies a high F1 score.
# 19  This is expected due to the Gaussian distribut...
# 20               Sigmoid can take on negative values.
# 21                                             Bias^2
# 22                                             Bias^2
# 23                                     Stays the same
# 24                                          Increases
#
#                                                     C  \
# 0                                      High variance.
# 1                                       Close to 0.5.
# 2        The precision is 1.0, and the recall is 0.9.
# 3                    y′ = [ y; 0d ], X′ = [ X; λ Id ]
# 4   If a matrix A is positive semi-definite, then ...
# 5   Lasso regression performs both feature expansi...
# 6   Increase the ℓ1 regularization penalty in the ...
# 7   Gradient descent converges to a globally optim...
# 8   For two discrete probability distributions P a...
# 9   During the k-fold cross validation process, we...
# 10  Replacing the first column of X by the sum of ...
# 11  The weight changes in a particular hidden laye...
# 12                        Bias will remain unchanged.
# 13                    Variance will remain unchanged.
# 14            For all X and y, ∥wridge∥_1 ≤ ∥wOLS∥_1.
# 15                As d → ∞, Acctrain approaches 100%.
# 16                                               9/10
# 17                                               9/10
# 18            A low F1 score implies a high variance.
# 19  This is expected due to the iterative nature o...
# 20  Sigmoid is non-linear, which provides less rep...
# 21                                           Variance
# 22                                           Variance
# 23                                          Decreases
# 24                                          Decreases
#
#                                                     D  \
# 0                                       Low variance.
# 1                                       Close to 0.9.
# 2        The precision is 0.9, and the recall is 1.0.
# 3                    y′ = [ y; 1d ], X′ = [ X; λ Id ]
# 4   The covariance matrix of any distribution is p...
# 5   There is no unique solution to Ridge regressio...
# 6                      Add new features to the model.
# 7   Since ReLU is a convex function, a neural netw...
# 8   Minimizing the cross-entropy is equivalent to ...
# 9   At the end of the k-fold cross validation proc...
# 10  Not subtracting the median from X before perfo...
# 11  Weight updates are computed in the forward pas...
# 12                  Decaf coldbrew latte is delicious
# 13                  Decaf coldbrew latte is delicious
# 14                  Decaf coldbrew latte is delicious
# 15                  As d → ∞, Accval approaches 100%.
# 16                                     more than 9/10
# 17                                     more than 9/10
# 18                  A high F1 score implies low bias.
# 19                  Decaf coldbrew latte is delicious
# 20  Sigmoid is numerically unstable when the input...
# 21                                         Variance^2
# 22                                         Variance^2
# 23                          Cappuccino is my favorite
# 24                                      Avocado toast
#
#                                                     E answer
# 0                                   none of the above      A
# 1                                       Close to one.      C
# 2        The precision is 0.1, and the recall is 1.0.      D
# 3                                   none of the above      A
# 4   If the Jacobian of a function is positive semi...      B
# 5                                   none of the above      B
# 6              Add synthetic features from the model.      A
# 7                                   none of the above      C
# 8                                   none of the above      A
# 9                                   none of the above      A
# 10                                  none of the above      B
# 11                                  none of the above      B
# 12                                  none of the above      A
# 13                                  none of the above      B
# 14                                  none of the above      C
# 15                                  none of the above      D
# 16                                  none of the above      C
# 17                                  none of the above      B
# 18                                  none of the above      D
# 19                                  none of the above      A
# 20                                  none of the above      A
# 21                                              Noise      E
# 22                       Cold brew latte is delicious      C
# 23                         The moon is made of cheese      C
# 24                                  Matcha cream puff      C

# %% [markdown]
# ### **Load Training Dataset (MMLU)**
#
# We will use the **MMLU (Massive Multitask Language Understanding)** dataset, specifically the `machine_learning` subset, as our training data. This helps the model learn general machine learning concepts which should transfer to the CS189 exam problems.

# %%
# === MMLU Helper Functions ===
def load_mmlu_dataset(subset: str = "machine_learning", split: str = "test"):
    """Load a subset of the MMLU dataset from Hugging Face."""
    print(f"Loading MMLU dataset (subset={subset}, split={split})...")
    ds = load_dataset("cais/mmlu", subset, split=split)
    return ds

def build_mmlu_prompt(row):
    """Prompt for inference: instruction + question + options."""
    q = str(row["question"]).strip()
    choices = row["choices"]

    options_list = []
    for i, choice in enumerate(choices):
        letter = chr(ord("A") + i)
        options_list.append(f"{letter}. {choice}")
    options_str = "\n".join(options_list)

    prompt = (
        "Choose exactly one correct option from the choices provided.\n"
        "Return your answer inside a LaTeX box.\n\n"
        f"{q}\n\n{options_str}\n\nAnswer:"
    )
    return prompt

def build_mmlu_sft_text(row, tokenizer):
    """Build properly formatted chat template text for training."""
    user_content = build_mmlu_prompt(row)

    answer_int = row["answer"]
    answer_letter = chr(ord("A") + answer_int)
    assistant_content = f"\\boxed{{{answer_letter}}}"

    messages = [
        {"role": "user", "content": user_content},
        {"role": "assistant", "content": assistant_content}
    ]

    return tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=False
    )

#     "clinical_knowledge",      "econometrics",     "moral_scenarios"
mmlu_subject_names = [
    "abstract_algebra",
    "college_computer_science",
    "college_mathematics",
    "college_physics",
    "business_ethics",
    "philosophy",
    "machine_learning",
    "econometrics",
    "moral_scenarios"
]

mmlu_text_datasets = []
for name in mmlu_subject_names:
    ds = load_mmlu_dataset(name, split="test")
    ds_text = ds.map(lambda x: {"text": build_mmlu_sft_text(x, tokenizer)})
    print(ds_text)
    mmlu_text_datasets.append(ds_text)

# balance the data set before concatinating the datasets
min_length = min([len(ds) for ds in mmlu_text_datasets])
print("Minimum Length of All DS is", min_length)
balanced_datasets = []

for ds in mmlu_text_datasets:
  if len(ds) > min_length:
    ds_bal = ds.shuffle(42).select(range(min_length))
  else:
    ds_bal = ds
  balanced_datasets.append(ds_bal)

final_text_ds = concatenate_datasets(balanced_datasets).shuffle(42)

print("Loaded MMLU ML dataset with", len(final_text_ds), "rows")

# Set the training dataset - you can mix and match datasets here
# Out:
# Loading MMLU dataset (subset=abstract_algebra, split=test)...
# README.md: 0.00B [00:00, ?B/s]
# dataset_infos.json: 0.00B [00:00, ?B/s]
# abstract_algebra/test-00000-of-00001.par(…):   0%|          | 0.00/9.96k [00:00<?, ?B/s]
# abstract_algebra/validation-00000-of-000(…):   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# abstract_algebra/dev-00000-of-00001.parq(…):   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'subject', 'choices', 'answer', 'text'],
#     num_rows: 100
# })
# Loading MMLU dataset (subset=college_computer_science, split=test)...
# college_computer_science/test-00000-of-0(…):   0%|          | 0.00/28.1k [00:00<?, ?B/s]
# college_computer_science/validation-0000(…):   0%|          | 0.00/6.25k [00:00<?, ?B/s]
# college_computer_science/dev-00000-of-00(…):   0%|          | 0.00/6.81k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'subject', 'choices', 'answer', 'text'],
#     num_rows: 100
# })
# Loading MMLU dataset (subset=college_mathematics, split=test)...
# college_mathematics/test-00000-of-00001.(…):   0%|          | 0.00/16.6k [00:00<?, ?B/s]
# college_mathematics/validation-00000-of-(…):   0%|          | 0.00/5.00k [00:00<?, ?B/s]
# college_mathematics/dev-00000-of-00001.p(…):   0%|          | 0.00/5.16k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'subject', 'choices', 'answer', 'text'],
#     num_rows: 100
# })
# Loading MMLU dataset (subset=college_physics, split=test)...
# college_physics/test-00000-of-00001.parq(…):   0%|          | 0.00/18.6k [00:00<?, ?B/s]
# college_physics/validation-00000-of-0000(…):   0%|          | 0.00/6.39k [00:00<?, ?B/s]
# college_physics/dev-00000-of-00001.parqu(…):   0%|          | 0.00/4.51k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/102 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]
# Map:   0%|          | 0/102 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'subject', 'choices', 'answer', 'text'],
#     num_rows: 102
# })
# Loading MMLU dataset (subset=business_ethics, split=test)...
# business_ethics/test-00000-of-00001.parq(…):   0%|          | 0.00/21.6k [00:00<?, ?B/s]
# business_ethics/validation-00000-of-0000(…):   0%|          | 0.00/5.09k [00:00<?, ?B/s]
# business_ethics/dev-00000-of-00001.parqu(…):   0%|          | 0.00/4.96k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'subject', 'choices', 'answer', 'text'],
#     num_rows: 100
# })
# Loading MMLU dataset (subset=philosophy, split=test)...
# philosophy/test-00000-of-00001.parquet:   0%|          | 0.00/48.6k [00:00<?, ?B/s]
# philosophy/validation-00000-of-00001.par(…):   0%|          | 0.00/9.15k [00:00<?, ?B/s]
# philosophy/dev-00000-of-00001.parquet:   0%|          | 0.00/4.20k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/311 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/34 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]
# Map:   0%|          | 0/311 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'subject', 'choices', 'answer', 'text'],
#     num_rows: 311
# })
# Loading MMLU dataset (subset=machine_learning, split=test)...
# machine_learning/test-00000-of-00001.par(…):   0%|          | 0.00/19.7k [00:00<?, ?B/s]
# machine_learning/validation-00000-of-000(…):   0%|          | 0.00/6.17k [00:00<?, ?B/s]
# machine_learning/dev-00000-of-00001.parq(…):   0%|          | 0.00/5.25k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/112 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]
# Map:   0%|          | 0/112 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'subject', 'choices', 'answer', 'text'],
#     num_rows: 112
# })
# Loading MMLU dataset (subset=econometrics, split=test)...
# econometrics/test-00000-of-00001.parquet:   0%|          | 0.00/24.5k [00:00<?, ?B/s]
# econometrics/validation-00000-of-00001.p(…):   0%|          | 0.00/7.02k [00:00<?, ?B/s]
# econometrics/dev-00000-of-00001.parquet:   0%|          | 0.00/4.54k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/114 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/12 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]
# Map:   0%|          | 0/114 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'subject', 'choices', 'answer', 'text'],
#     num_rows: 114
# })
# Loading MMLU dataset (subset=moral_scenarios, split=test)...
# moral_scenarios/test-00000-of-00001.parq(…):   0%|          | 0.00/89.8k [00:00<?, ?B/s]
# moral_scenarios/validation-00000-of-0000(…):   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# moral_scenarios/dev-00000-of-00001.parqu(…):   0%|          | 0.00/5.14k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/895 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]
# Map:   0%|          | 0/895 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'subject', 'choices', 'answer', 'text'],
#     num_rows: 895
# })
# Minimum Length of All DS is 100
# Loaded MMLU ML dataset with 900 rows

# %%
#load CS189 training data
def build_mcq_sft_text(row, tokenizer):
    """Build properly formatted chat template text for MCQ training."""
    user_content = build_mcq_prompt(row)
    answer_letter = row["answer"]
    assistant_content = f"\\boxed{{{answer_letter}}}"

    messages = [
        {"role": "user", "content": user_content},
        {"role": "assistant", "content": assistant_content}
    ]

    return tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=False
    )

# split mcq_df into train/eval
from sklearn.model_selection import train_test_split
train_mcq, eval_mcq = train_test_split(mcq_df, test_size=0.2, random_state=42)

# convert to HF Dataset
cs189_train = Dataset.from_pandas(train_mcq)
cs189_train = cs189_train.map(lambda x: {"text": build_mcq_sft_text(x, tokenizer)})

#keep only the 'text' column to match MMLU format
cs189_train = cs189_train.remove_columns([col for col in cs189_train.column_names if col != 'text'])
cs189_repeated = concatenate_datasets([cs189_train] * 3) # upsample CS189 data to give it more weight

train_dataset = concatenate_datasets([final_text_ds, cs189_repeated]).shuffle(42)

print(f"Combined training dataset size: {len(train_dataset)}")
print(f"  - MMLU examples: {len(final_text_ds)}")
print(f"  - CS189 examples (repeated): {len(cs189_repeated)}")
# Out:
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Combined training dataset size: 960
#   - MMLU examples: 900
#   - CS189 examples (repeated): 60

# %% [markdown]
# Let's look at an example of the training data to see what the model is actually seeing as input. Note that there are now start and stop tokens `<|im_start|>` and `<|im_end|>` as well as the role `user` and `assistant` indicating who is speaking.

# %%
# print out what the first row looks like
print(train_dataset[0]['text'])
#print(train_dataset[0])
# Out:
# <|im_start|>system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>
# <|im_start|>user
# Choose exactly one correct option from the choices provided.
# Return your answer inside a LaTeX box.
#
# Which of the following is a typical characteristic of financial asset return time-series?
#
# A. Their distributions are thin-tailed
# B. They are not weakly stationary
# C. They are highly autocorrelated
# D. They have no trend
#
# Answer:<|im_end|>
# <|im_start|>assistant
# \boxed{D}<|im_end|>

# %% [markdown]
# ---
# ## Part 3: Baseline Evaluation
#
# **Predict & Evaluate (O):** Before we train, let's see how the model performs "zero-shot" or "few-shot" (depending on the prompt) on our CS189 questions.

# %%
def eval_mcq_accuracy(
    curr_model,
    curr_tokenizer,
    df,
    max_new_tokens: int = 64,
    return_details: bool = False,
):
    """Evaluate a model on the MCQ dataset using greedy decoding.

    If return_details=True, also return a pandas DataFrame with
    [idx, question, A, B, C, D, E, gold, decoded, parsed, correct].
    """
    curr_model.eval()
    n = len(df)
    correct = 0
    total = 0
    records = []

    for idx in range(n):
        row = df.iloc[idx]
        user_content = build_mcq_prompt(row)

        # Apply chat template for inference
        messages = [{"role": "user", "content": user_content}]
        prompt = curr_tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True
        )

        inputs = curr_tokenizer(prompt, return_tensors="pt").to(device)

        with torch.no_grad():
            outputs = curr_model.generate(
                **inputs,
                max_new_tokens=max_new_tokens,
                do_sample=False,
            )

        gen_tokens = outputs[0][inputs["input_ids"].shape[1]:]
        decoded = curr_tokenizer.decode(gen_tokens, skip_special_tokens=True)

        pred = parse_choice_from_boxed(decoded)
        is_correct = (pred is not None and pred == row["answer"])
        if is_correct:
            correct += 1
        total += 1

        records.append({
            "idx": idx,
            "question": row["question"],
            "A": row["A"],
            "B": row["B"],
            "C": row["C"],
            "D": row["D"],
            "E": row["E"],
            "gold": row["answer"],
            "prompt": prompt,
            "decoded": decoded,
            "parsed": pred,
            "correct": is_correct,
        })

        if (idx + 1) % 20 == 0:
            print(f"Processed {idx + 1}/{n} questions...")

    acc = correct / max(total, 1)
    print(f"MCQ accuracy: {acc * 100:.2f}% ({correct}/{total})")

    details_df = pd.DataFrame(records)
    if return_details:
        return acc, details_df
    return acc

# === Baseline MCQ accuracy before fine-tuning ===
print("Evaluating baseline model on MCQ dataset...")
baseline_acc, baseline_details = eval_mcq_accuracy(
    model,
    tokenizer,
    mcq_df,
    max_new_tokens=EVAL_MAX_NEW_TOKENS,
    return_details=True,
)
baseline_details.head()
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating baseline model on MCQ dataset...
# Processed 20/25 questions...
# MCQ accuracy: 28.00% (7/25)
#    idx                                           question  \
# 0    0  Peanut wants to train a model to accurately cl...
# 1    1  Consider a binary classification data set with...
# 2    2  Again, consider a binary classification data s...
# 3    3  Assume we are given X ∈ Rn×d and y ∈ Rn for n ...
# 4    4  Which of the following statements are TRUE reg...
#
#                                                    A  \
# 0                                         High bias.
# 1                                     Close to zero.
# 2       The precision is 0.1, and the recall is 0.9.
# 3                  y′ = [ y; 0d ], X′ = [ X; √λ Id ]
# 4  “Every entry of a matrix is non-negative” is a...
#
#                                                    B  \
# 0                                          Low bias.
# 1                                      Close to 0.1.
# 2       The precision is 0.9, and the recall is 0.1.
# 3                  y′ = [ y; 1d ], X′ = [ X; √λ Id ]
# 4  The singular values of a positive semi-definit...
#
#                                                    C  \
# 0                                     High variance.
# 1                                      Close to 0.5.
# 2       The precision is 1.0, and the recall is 0.9.
# 3                   y′ = [ y; 0d ], X′ = [ X; λ Id ]
# 4  If a matrix A is positive semi-definite, then ...
#
#                                                    D  \
# 0                                      Low variance.
# 1                                      Close to 0.9.
# 2       The precision is 0.9, and the recall is 1.0.
# 3                   y′ = [ y; 1d ], X′ = [ X; λ Id ]
# 4  The covariance matrix of any distribution is p...
#
#                                                    E gold  \
# 0                                  none of the above    A
# 1                                      Close to one.    C
# 2       The precision is 0.1, and the recall is 1.0.    D
# 3                                  none of the above    A
# 4  If the Jacobian of a function is positive semi...    B
#
#                                               prompt  \
# 0  <|im_start|>system\nYou are Qwen, created by A...
# 1  <|im_start|>system\nYou are Qwen, created by A...
# 2  <|im_start|>system\nYou are Qwen, created by A...
# 3  <|im_start|>system\nYou are Qwen, created by A...
# 4  <|im_start|>system\nYou are Qwen, created by A...
#
#                                              decoded parsed  correct
# 0  To determine what we can most confidently say ...      A     True
# 1  To determine the area under the ROC curve (AUC...      A    False
# 2  To determine the precision and recall for a cl...      A    False
# 3  To determine which modified version of \(X\) a...      A     True
# 4  To determine which statement is true regarding...      A    False

# %% [markdown]
# ---
# ## Part 4: Training (Optimization)
#
# **Optimization (M):** We now configure the `SFTTrainer`.
#
# We set:
# - `dataset_text_field="text"`: Tells the trainer which column contains the formatted chat.
# - `learning_rate`, `batch_size`: Standard hyperparameters.
# - `optim="adamw_8bit"`: Efficient optimizer.

# %%
# === Set up SFTTrainer ===
sft_config = SFTConfig(
    dataset_text_field="text",
    per_device_train_batch_size=TRAIN_BATCH_SIZE,
    gradient_accumulation_steps=GRADIENT_ACCUMULATION_STEPS,
    warmup_steps=WARMUP_STEPS,
    max_steps=MAX_STEPS,
    learning_rate=LEARNING_RATE,
    logging_steps=1,
    optim=OPTIM,
    weight_decay=WEIGHT_DECAY,
    lr_scheduler_type=LR_SCHEDULER_TYPE,
    seed=SEED,
    report_to="none",
)

trainer = SFTTrainer(
    model=model,
    args=sft_config,
    train_dataset=train_dataset,
    eval_dataset=None,
    processing_class=tokenizer,
)

trainer
# Out:
# Adding EOS to train dataset:   0%|          | 0/960 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/960 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/960 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.

# %% [markdown]
# ### Run Training
#
# This will iterate through the dataset and update the model's weights.

# %%
# === Fine-tune the model ===
model.train()
trainer.train()
model.eval()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1500665377.py in <cell line: 0>()
#       1 # === Fine-tune the model ===
#       2 model.train()
# ----> 3 trainer.train()
#       4 model.eval()
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2323                 hf_hub_utils.enable_progress_bars()
#    2324         else:
# -> 2325             return inner_training_loop(
#    2326                 args=args,
#    2327                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2672                     )
#    2673                     with context():
# -> 2674                         tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2675
#    2676                     if (
#
# /usr/local/lib/python3.12/dist-packages/trl/trainer/sft_trainer.py in training_step(self, *args, **kwargs)
#    1243     def training_step(self, *args, **kwargs):
#    1244         with self.maybe_activation_offload_context:
# -> 1245             return super().training_step(*args, **kwargs)
#    1246
#    1247     def log(self, logs: dict[str, float], start_time: float | None = None) -> None:
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in training_step(***failed resolving arguments***)
#    4069                     kwargs["scale_wrt_gas"] = False
#    4070
# -> 4071                 self.accelerator.backward(loss, **kwargs)
#    4072
#    4073             return loss.detach()
#
# /usr/local/lib/python3.12/dist-packages/accelerate/accelerator.py in backward(self, loss, **kwargs)
#    2850             self.lomo_backward(loss, learning_rate)
#    2851         else:
# -> 2852             loss.backward(**kwargs)
#    2853
#    2854     def set_trigger(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     839         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840     try:
# --> 841         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842             t_outputs, *args, **kwargs
#     843         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# ## Part 5: Post-Training Evaluation
#
# **Predict & Evaluate (O):** Now that the model is trained, we evaluate it again on the same MCQ dataset to see if accuracy improved.

# %%
# === Evaluate MCQ accuracy after fine-tuning ===
print("Evaluating fine-tuned model on MCQ dataset...")
ft_acc, ft_details = eval_mcq_accuracy(
    model,
    tokenizer,
    mcq_df,
    max_new_tokens=EVAL_MAX_NEW_TOKENS,
    return_details=True,
)
ft_details.head()
print(f"Baseline acc: {baseline_acc:.4f}, Fine-tuned acc: {ft_acc:.4f}")

# %% [markdown]
# ### Save the Model
#
# We save the fine-tuned model and tokenizer so we can use them later.

# %%
# === Save fine-tuned model (optional) ===
os.makedirs(OUTPUT_DIR, exist_ok=True)
trainer.model.save_pretrained(OUTPUT_DIR)
tokenizer.save_pretrained(OUTPUT_DIR)
print("Saved fine-tuned model to", OUTPUT_DIR)

# %% [markdown]
# ---

# %% [markdown]
# ## 🧩 **YOUR TURN — Final Kaggle Submission**
#
# Now it’s your turn to run the *full* ML lifecycle.
#
# You should now be able to load and inspect the **private test CSV**, which contains **169 questions** with mixed types.
# Use your **fine-tuned LLM** to make predictions on these questions.
# **Beware of formatting**: Kaggle will reject incorrectly formatted submissions!
#
# ### Objective
#
# Your task is to:
#
# 1. **Use the provided notebook** to fine-tune the base model on your own choice of train data (feel free to adapt the one we provided)
# 2. **Adapt the same pipeline** to run inference on `test.csv`.
# 3. For each row in `test.csv`, output **exactly one letter** from the set
#    **{A, B, C, D, E}**.
# 4. Save these predictions in the **strict submission format** described below and
#    upload your CSV to Kaggle:
#    - https://www.kaggle.com/t/11c8ffdc967fe3f27755cde6fb5810e8

# %% [markdown]
# ### **Submission Format (Strict)**
#
# Your submission must be a **CSV** with exactly **two columns** — `id` and `prediction` — and a **single header row**.
#
# A valid submission looks like:
#
# | id          | prediction |
# |-------------|------------|
# | test_00001  | A          |
# | test_00002  | A          |
# | test_00003  | C          |
# | test_00004  | E          |
# | ...         | ...        |

# %% [markdown]
# ### Evaluation Metric
#
# Submissions are evaluated using **accuracy**: the fraction of test examples for which your
# predicted answer matches the hidden correct answer.
#
#
# ### Example
#
# | **id**        | **True Answer** | **Your Prediction** | **Correct?** |
# |---------------|-----------------|---------------------|--------------|
# | `test_00001`  | A               | A                   | Yes          |
# | `test_00002`  | A               | B                   | No           |
# | `test_00003`  | A               | A                   | Yes          |
#
# Here, the accuracy would be 2/3, or approximately 66.7%
#
# The leaderboard is split into:
#
# - **Public leaderboard**: 50% of the test data
# - **Private leaderboard**: remaining 50% (used for final ranking and grading)

# %%
YOUR_PATH_TO_TEST_CSV = 'kaggle_test.csv' #TODO: REPLACE WITH YOUR OWN PATH
test_questions = pd.read_csv(YOUR_PATH_TO_TEST_CSV)
test_questions
#TODO:
# 1. Make predictions on your finetuned model
def predict_mcq(model, tokenizer, max_new_tokens=64):
  preds = []

  for _, row in test_questions.iterrows():
    user_text = build_mcq_prompt(row)
    messages = [{"role": "user", "content": user_text}]
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(prompt, return_tensors="pt").to(device)

    with torch.no_grad():
      outputs = model.generate(
                **inputs,
                max_new_tokens=max_new_tokens,
                do_sample=False,
            )

    gen_tokens = outputs[0][inputs["input_ids"].shape[1]:]
    decoded = tokenizer.decode(gen_tokens, skip_special_tokens=True)
    pred = parse_choice_from_boxed(decoded)
    if pred is None:
      pred = "A"

    preds.append(pred)
  return preds


# 2. submit to kaggle following the expected format (id, prediction)
submission = pd.DataFrame({
    "id": test_questions["id"],
    "prediction": predict_mcq(model, tokenizer, EVAL_MAX_NEW_TOKENS)
})

submission.to_csv("submission7.csv", index=False)
print("Saved submission.csv")

submission.head()

# %%
YOUR_PATH_TO_TEST_CSV = 'kaggle_test.csv' #TODO: REPLACE WITH YOUR OWN PATH
test_questions = pd.read_csv(YOUR_PATH_TO_TEST_CSV)

def test_eval(
    curr_model,
    curr_tokenizer,
    df,
    max_new_tokens: int = 64,
    return_details: bool = False,
):
    """Evaluate a model on the MCQ dataset using greedy decoding.

    If return_details=True, also return a pandas DataFrame with
    [idx, question, A, B, C, D, E, gold, decoded, parsed, correct].
    """
    curr_model.eval()
    n = len(df)
    total = 0
    records = []

    for idx in range(n):
        row = df.iloc[idx]
        user_content = build_mcq_prompt(row)

        # Apply chat template for inference
        messages = [{"role": "user", "content": user_content}]
        prompt = curr_tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True
        )

        inputs = curr_tokenizer(prompt, return_tensors="pt").to(device)

        with torch.no_grad():
            outputs = curr_model.generate(
                **inputs,
                max_new_tokens=max_new_tokens,
                do_sample=False,
            )

        gen_tokens = outputs[0][inputs["input_ids"].shape[1]:]
        decoded = curr_tokenizer.decode(gen_tokens, skip_special_tokens=True)

        pred = parse_choice_from_boxed(decoded)

        records.append({
            "idx": idx,
            "question": row["question"],
            "A": row["A"],
            "B": row["B"],
            "C": row["C"],
            "D": row["D"],
            "E": row["E"],
            "prompt": prompt,
            "decoded": decoded,
            "parsed": pred,
        })

        if (idx + 1) % 20 == 0:
            print(f"Processed {idx + 1}/{n} questions...")

    details_df = pd.DataFrame(records)

    return details_df

print("Evaluating baseline model on test dataset...")
test_baseline_details = test_eval(
    model,
    tokenizer,
    test_questions,
    max_new_tokens=EVAL_MAX_NEW_TOKENS,
    return_details=False,
)

test_baseline_details.head()
# Out:
# Evaluating baseline model on test dataset...
# Processed 20/169 questions...
# Processed 40/169 questions...
# Processed 60/169 questions...
# Processed 80/169 questions...
# Processed 100/169 questions...
# Processed 120/169 questions...
# Processed 140/169 questions...
# Processed 160/169 questions...
#    idx                                           question  \
# 0    0  Peanut wants to train a model to accurately cl...
# 1    1  Consider a binary classification data set with...
# 2    2  Again, consider a binary classification data s...
# 3    3  Assume we are given X ∈ Rn×d and y ∈ Rn for n ...
# 4    4  Which of the following statements are TRUE reg...
#
#                                                    A  \
# 0                                         High bias.
# 1                                     Close to zero.
# 2       The precision is 0.1, and the recall is 0.9.
# 3                  y′ = [ y; 0d ], X′ = [ X; √λ Id ]
# 4  “Every entry of a matrix is non-negative” is a...
#
#                                                    B  \
# 0                                          Low bias.
# 1                                      Close to 0.1.
# 2       The precision is 0.9, and the recall is 0.1.
# 3                  y′ = [ y; 1d ], X′ = [ X; √λ Id ]
# 4  The singular values of a positive semi-definit...
#
#                                                    C  \
# 0                                     High variance.
# 1                                      Close to 0.5.
# 2       The precision is 1.0, and the recall is 0.9.
# 3                   y′ = [ y; 0d ], X′ = [ X; λ Id ]
# 4  If a matrix A is positive semi-definite, then ...
#
#                                                    D  \
# 0                                      Low variance.
# 1                                      Close to 0.9.
# 2       The precision is 0.9, and the recall is 1.0.
# 3                   y′ = [ y; 1d ], X′ = [ X; λ Id ]
# 4  The covariance matrix of any distribution is p...
#
#                                                    E  \
# 0                                  none of the above
# 1                                      Close to one.
# 2       The precision is 0.1, and the recall is 1.0.
# 3                                  none of the above
# 4  If the Jacobian of a function is positive semi...
#
#                                               prompt    decoded parsed
# 0  <|im_start|>system\nYou are Qwen, created by A...  \boxed{C}      C
# 1  <|im_start|>system\nYou are Qwen, created by A...  \boxed{C}      C
# 2  <|im_start|>system\nYou are Qwen, created by A...  \boxed{A}      A
# 3  <|im_start|>system\nYou are Qwen, created by A...  \boxed{A}      A
# 4  <|im_start|>system\nYou are Qwen, created by A...  \boxed{A}      A

# %%
test_baseline_details.to_csv("test_baseline_details.csv", index=False)

# %%
# # Dummy Place Holder

# # Create a dummy submission dataframe with all "A"
# submission = pd.DataFrame({
#     "id": test_questions["id"],
#     "prediction": ["A"] * len(test_questions)
# })

# # Save to CSV
# submission.to_csv("dummy_submission.csv", index=False)

# print("Saved dummy_submission.csv")
# submission.head()
